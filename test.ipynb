# %%
from utils.config import *
from utils.utils import *
import torch
# pd.set_option('display.max_columns', None) 
# pd.set_option('max_colwidth', None) # show full width of showing cols
# pd.set_option("expand_frame_repr", False) # print cols side by side as it's supposed to be

# %%
# read_from_sqlite(LINKEDIN_DB_FILE, LINKEDIN_JOB_DETAILS_TABLE)

# %%
df= read_from_sqlite(LINKEDIN_DB_FILE, LINKEDIN_FORM_QA_TABLE)
df
# Out:
#                                              question             pre_ans  \
# 0                                          First name               Manab
# 1                                           Last name                Boro
# 2                                  Phone country code         India (+91)
# 3                                 Mobile phone number        919101925089
# 4                                       Email address  mboro497@gmail.com
# 5                                     Location (city)
# 6                                       Email address  mboro497@gmail.com
# 7                                  Phone country code         India (+91)
# 8                                 Mobile phone number        919101925089
# 9   Have you completed the following level of educ...                 Yes
# 10  How many years of work experience do you have ...
# 11  How many years of work experience do you have ...
# 12                                      Email address  mboro497@gmail.com
# 13                                 Phone country code         India (+91)
# 14                                Mobile phone number        919101925089
# 15  How many years of work experience do you have ...                   2
# 16  How many years of work experience do you have ...                   2
# 17  How many years of work experience do you have ...                   0
# 18  How many years of work experience do you have ...
# 19  Are you serving Notice Period? Can you join in...    Select an option
# 20                                      Email address  mboro497@gmail.com
# 21                                 Phone country code         India (+91)
# 22                                Mobile phone number        919101925089
# 23  How many years of work experience do you have ...                   0
# 24  How many years of work experience do you have ...                   1
# 25  How many years of work experience do you have ...                   2
#
#              predicted_ans input_type predicted_question_type  \
# 0               Manab Boro       text    personal_information
# 1               Manab Boro       text    personal_information
# 2              India (+91)     select    personal_information
# 3             919101925089       text    personal_information
# 4       mboro497@gmail.com     select    personal_information
# 5   Guwahati, Assam, India       text    personal_information
# 6       mboro497@gmail.com     select    personal_information
# 7              India (+91)     select    personal_information
# 8             919101925089       text    personal_information
# 9                     None      radio                    None
# 10                    7510       text                  skills
# 11                    6510       text                  skills
# 12      mboro497@gmail.com     select    personal_information
# 13             India (+91)     select    personal_information
# 14            919101925089       text    personal_information
# 15                    None       text                    None
# 16                     810       text                  skills
# 17                    None       text                    None
# 18                      75       text                  skills
# 19                      No     select            availability
# 20      mboro497@gmail.com     select    personal_information
# 21             India (+91)     select    personal_information
# 22            919101925089       text    personal_information
# 23                    7510       text                  skills
# 24                    7510       text                  skills
# 25                    None       text                    None
#
#                                     available_options applied_successfully  \
# 0                                                  []                    N
# 1                                                  []                    N
# 2   ["Select an option", "India (+91)", "Afghanist...                    N
# 3                                                  []                    N
# 4          ["Select an option", "mboro497@gmail.com"]                    N
# 5                                                  []                    N
# 6          ["Select an option", "mboro497@gmail.com"]                    N
# 7   ["Select an option", "India (+91)", "Afghanist...                    N
# 8                                                  []                    N
# 9                                       ["Yes", "No"]                    N
# 10                                                 []                    N
# 11                                                 []                    N
# 12         ["Select an option", "mboro497@gmail.com"]                    N
# 13  ["Select an option", "India (+91)", "Afghanist...                    N
# 14                                                 []                    N
# 15                                                 []                    N
# 16                                                 []                    N
# 17                                                 []                    N
# 18                                                 []                    N
# 19                  ["Select an option", "Yes", "No"]                    N
# 20         ["Select an option", "mboro497@gmail.com"]                    N
# 21  ["Select an option", "India (+91)", "Afghanist...                    N
# 22                                                 []                    N
# 23                                                 []                    N
# 24                                                 []                    N
# 25                                                 []                    N
#
#             inserted_at
# 0   2025-02-01 22:04:04
# 1   2025-02-01 22:04:04
# 2   2025-02-01 22:04:04
# 3   2025-02-01 22:04:04
# 4   2025-02-01 22:04:04
# 5   2025-02-01 22:04:04
# 6   2025-02-01 22:05:16
# 7   2025-02-01 22:05:16
# 8   2025-02-01 22:05:16
# 9   2025-02-01 22:05:16
# 10  2025-02-01 22:05:16
# 11  2025-02-01 22:05:16
# 12  2025-02-01 22:15:51
# 13  2025-02-01 22:15:51
# 14  2025-02-01 22:15:51
# 15  2025-02-01 22:15:51
# 16  2025-02-01 22:15:51
# 17  2025-02-01 22:15:51
# 18  2025-02-01 22:15:51
# 19  2025-02-01 22:15:51
# 20  2025-02-01 22:16:53
# 21  2025-02-01 22:16:53
# 22  2025-02-01 22:16:53
# 23  2025-02-01 22:16:53
# 24  2025-02-01 22:16:53
# 25  2025-02-01 22:16:53

# %%
# read_from_sqlite(LINKEDIN_DB_FILE, LINKEDIN_POSTS_DETAILS_TABLE)
