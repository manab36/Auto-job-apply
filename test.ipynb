# %%
# from Linkedin.Linkedin import Linkedin
from Linkedin.LinkedinJobApply import LinkedinJobApply
# from Linkedin.LinkedinPostScrape import LinkedinPostScrape



# Linkedin()
# LinkedinJobApply_obj= LinkedinJobApply()
# LinkedinJobApply_obj.run()

# LinkedinJobApply_obj= LinkedinPostScrape()
# LinkedinJobApply_obj.run()
# Out:
# ---------------------------------------Processing jobs for title: Data Engineer---------------------------------------
# total jobs found 1382
# Estimated number of pages: 54
# Processing jobs on current page: 1: 100%|██████████| 25/25 [01:07<00:00,  2.71s/it]
# Processing jobs on current page: 2: 100%|██████████| 25/25 [01:04<00:00,  2.60s/it]
# Processing jobs on current page: 3: 100%|██████████| 25/25 [01:03<00:00,  2.54s/it]
# Processing jobs on current page: 4: 100%|██████████| 25/25 [01:01<00:00,  2.48s/it]
# Processing jobs on current page: 5: 100%|██████████| 25/25 [01:02<00:00,  2.49s/it]
# Processing jobs: 100%|██████████| 5/5 [06:51<00:00, 82.39s/it]
# ---------------------------------------Processing jobs for title: Python Developer---------------------------------------
# total jobs found 814
# Estimated number of pages: 31
# Processing jobs on current page: 1: 100%|██████████| 25/25 [01:01<00:00,  2.48s/it]
# Processing jobs on current page: 2: 100%|██████████| 25/25 [01:02<00:00,  2.50s/it]
# Processing jobs on current page: 3: 100%|██████████| 25/25 [01:03<00:00,  2.53s/it]
# Processing jobs on current page: 4: 100%|██████████| 25/25 [01:02<00:00,  2.51s/it]
# Processing jobs on current page: 5: 100%|██████████| 25/25 [01:02<00:00,  2.50s/it]
# Processing jobs: 100%|██████████| 5/5 [06:43<00:00, 80.77s/it]
# ---------------------------------------Processing jobs for title: Python Engineer---------------------------------------
# total jobs found 548
# Estimated number of pages: 21
# Processing jobs on current page: 1: 100%|██████████| 25/25 [01:02<00:00,  2.51s/it]
# Processing jobs:  20%|██        | 1/5 [01:21<05:26, 81.54s/it]
