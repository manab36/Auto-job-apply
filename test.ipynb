# %%
from utils.config import *
from utils.utils import *
import torch
import gc
from sentence_transformers import SentenceTransformer
from sklearn.metrics.pairwise import cosine_similarity
from transformers import DistilBertTokenizerFast, DistilBertForSequenceClassification, T5ForConditionalGeneration, T5Tokenizer
from utils.model_pipelines import predict_ans
pd.set_option('display.max_columns', None) 
pd.set_option('max_colwidth', None) # show full width of showing cols
pd.set_option("expand_frame_repr", False) # print cols side by side as it's supposed to be

# %%
df= read_from_sqlite(LINKEDIN_DB_FILE, LINKEDIN_JOB_DETAILS_TABLE)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 423 entries, 0 to 422
# Data columns (total 17 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   job_title                 423 non-null    object
#  1   job_location              423 non-null    object
#  2   job_posted                423 non-null    object
#  3   total_applicant           423 non-null    object
#  4   company_name              423 non-null    object
#  5   company_link              423 non-null    object
#  6   company_type              423 non-null    object
#  7   company_size              423 non-null    object
#  8   company_size_on_linkedin  423 non-null    object
#  9   job_description           423 non-null    object
#  10  job_linkedin_link         423 non-null    object
#  11  is_easy_apply             423 non-null    object
#  12  emails_found              423 non-null    object
# ...

# %% [markdown]
# # Test

# %%
# df= read_from_sqlite(LINKEDIN_DB_FILE, LINKEDIN_FORM_QA_TABLE)[["question", "raw_predicted_ans", "filtered_predicted_ans", "input_type", "predicted_question_type"]].drop_duplicates()
# df

# %%
# read_from_sqlite(LINKEDIN_DB_FILE, LINKEDIN_POSTS_DETAILS_TABLE)
