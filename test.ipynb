# %%
from utils.config import *
from utils.utils import *
import torch
import gc
from sentence_transformers import SentenceTransformer
from sklearn.metrics.pairwise import cosine_similarity
from transformers import DistilBertTokenizerFast, DistilBertForSequenceClassification, T5ForConditionalGeneration, T5Tokenizer
from utils.model_pipelines import predict_ans
pd.set_option('display.max_columns', None) 
pd.set_option('max_colwidth', None) # show full width of showing cols
pd.set_option("expand_frame_repr", False) # print cols side by side as it's supposed to be

# %%
# df= read_from_sqlite(LINKEDIN_DB_FILE, LINKEDIN_JOB_DETAILS_TABLE)
# df.info()

# %% [markdown]
# # Test

# %%
df= read_from_sqlite(LINKEDIN_DB_FILE, LINKEDIN_FORM_QA_TABLE)[["question", "raw_predicted_ans", "filtered_predicted_ans", "input_type", "predicted_question_type"]].drop_duplicates()
df
# Out:
#                                                                       question   raw_predicted_ans filtered_predicted_ans input_type predicted_question_type
# 0                                                                Email address  mboro497@gmail.com     mboro497@gmail.com     select    personal_information
# 1                                                           Phone country code          9101925089        Djibouti (+253)     select    personal_information
# 2                                                          Mobile phone number          9101925089             9101925089       text    personal_information
# 3                                       How many years of total exp you have ?                   2                      2       text                  skills
# 4                                         What is your notice period in days ?                  30                     30       text            availability
# ...                                                                        ...                 ...                    ...        ...                     ...
# 3038                                           What is your current location ?        Assam, India              Hyderabad     select    personal_information
# 3044                  How many years of work experience do you have with JSON?                   1                      1       text                  skills
# 3046        How many years of work experience do you have in Data Structures ?                   2                      2       text                  skills
# 3047          How many years of work experience do you have in RESTFful APIs ?                   2                      2       text                  skills
# 3048  Are you available immediately for virtual & F2F interview in Bengaluru ?                 Yes                    Yes     select            availability
#
# [631 rows x 5 columns]

# %%
# read_from_sqlite(LINKEDIN_DB_FILE, LINKEDIN_POSTS_DETAILS_TABLE)
